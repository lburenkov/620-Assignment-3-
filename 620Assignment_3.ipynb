# %% [markdown]
# Assignment 3: Graph Visualization

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
# Set the parameters
# %matplotlib inline
rcParams['figure.figsize'] = 5, 4

# %%
# Read 500 rows
dt = pd.read_excel("network_list.xlsx")
dt
# Out:
#     NETWORK  NUMBER_OF_PARTICIPANTS
# 0         0                       7
# 1         1                       8
# 2         2                       7
# 3         3                       7
# 4         4                       8
# ..      ...                     ...
# 57       57                       8
# 58       58                       8
# 59       59                       7
# 60       60                       7
# 61       61                       8
#
# [62 rows x 2 columns]

# %%
dt.shape
# Out:
# (62, 2)

# %%
G = nx.from_pandas_edgelist(dt, source='NETWORK', target='NUMBER_OF_PARTICIPANTS')
nx.draw_networkx(G)

# %%
print(G)
# Out:
# Graph with 62 nodes and 61 edges

# %%
nx.algorithms.diameter(G)
# Out:
# 5

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
nx.draw(G, node_color='bisque', with_labels=True)
